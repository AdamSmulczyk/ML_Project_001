# %% [markdown]
# # Author Details:
# - Name: Adam Smulczyk
# - Email: adam.smulczyk@gmail.com
# - Profile: [Github](https://github.com/AdamSmulczyk)
# - [Github Repository](https://github.com/AdamSmulczyk/ML_Project_001)

# %% [markdown]
# <a id="1.2"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Table of Contents ℹ️</div>

# %% [markdown]
# <a id="toc"></a>
# - [I. PLANNING](#I)
#     - [I.1 Introduction](#I.1)
#     - [I.2 Dataset Description](#I.2)
#     - [I.3 Project assumptions](#I.3)
#         - [I.3.1 Defining the problem](#I.3.1)
#         - [I.3.2 Assessing the scope](#I.3.2)
#         - [I.3.3 Success metric](#I.3.3)
#         - [I.3.4 Feasibility  of the ML application](#I.3.4)
# - [II.DATA COLLECTION AND PREPARATION](#II)
#     - [II.1 Import libraries and data files](#II.1)
#     - [II.2 Exploratory Data Analysis (EDA)](#II.2)
#         - [II.2.1 Reading Data & Target Class Distribution](#II.2.1)
#         - [II.2.2 Statistical Summary](#II.2.2)
#         - [II.2.3 Correlation Matrics](#II.2.3)
#         - [II.2.4 Missing values](#II.2.4)
#         - [II.2.5 Finding any relations or trends considering multiple features](#II.2.5)
#             - [II.2.5.1  Distribution of numerical features](#II.2.5.1)
#             - [II.2.5.2  Dependency diagram 'Survived' - 'Pclass'](#II.2.5.2)
#             - [II.2.5.3  Dependency diagram 'Survived' – 'Pclass' – 'Sex'](#II.2.5.3)
#             - [II.2.5.4  Dependency diagram 'Survived' – 'Sex'](#II.2.5.4)
#             - [II.2.5.5  Analysis of survival chances by age group](#II.2.5.5)
#             - [II.2.5.6  Analysis of 'Embarked'](#II.2.5.6)
#             - [II.2.5.7  Analysis of survival chances depending on family size](#II.2.5.7)
#             - [II.2.5.8  Analysis of survival chances depending on 'Age' – 'Fare'](#II.2.5.8)
# - [III DATA PRE-PROCESSING (data cleaning)](#III)
#     - [III.1 Convert Types (Downcasting)](#III.1)
#     - [III.2 Feature Engineerin](#III.2)
#     - [III.3 Skewness of distributions](#III.3)
#     - [III.4 Detect Outlier](#III.4)
# - [IV DATA PROCESSING](#IV)
#     - [IV.1 Filling nulls](#IV.1)
#     - [IV.2 Categorical data transformation](#IV.2)
#     - [IV.3 Normalizing data](#IV.3)
# - [V MODEL ENGINEERING](#V)
#     - [V.1 Model 1](#V.1)
#         - [V.1.1 Model 1 Tuning - RandomearchCV](#V.1.1)
#         - [V.1.2 Model 1 Validation](#V.1.2)
#     - [V.2 Model 2](#V.2)
#         - [V.2.1 Model 2 Tuning - RandomizedSearchCV](#V.2.1)
#         - [V.2.2 Model 2 Validation](#V.2.2)
#     - [V.3 Model 3](#V.3)
#         - [V.3.1 Model 3 Tuning - RandomSearch](#V.3.1)
#         - [V.3.2 Model 3 Validation](#V.3.2)
# - [VI CONCLUSION](#VI)

# %% [markdown]
# <a id="I"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">I <span style='color:#CDA63A'>|</span>PLANNING 👨‍🏫</div>

# %% [markdown]
#  ### <a id="I.1"></a><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.1 Introduction</p>

# %% [markdown]
# The sinking of the **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">Titanic</mark>** is one of the most infamous shipwrecks in history. On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg.
#
# Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">1502 out of 2224</mark>** passengers and crew. It took about $7.5 million to build the Titanic and it sunk under the ocean due to collision.
#
# This is a very unforgetable disaster that no one in the world can forget. While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this task is to build a predictive model that answers the question: “what sorts of people were more likely to survive?”

# %% [markdown]
#  ### <a id="I.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.2 Dataset Description</p>

# %% [markdown]
# Two data sets are provided, a training set and a test set.  The PassengerID variable is assumed to be a random, unique identifier that has no effect on the outcome variable. Therefore, it will be excluded from the analysis. All other variables are potential predictors or independent variables.  The training set therefore consists of 10 predictor attributes, which include:
#
# * <code>PassengerID:</code> Passenger ID
# * <code>Survival:</code>  The 'Survival' variable is our outcome or dependent variable. It is a binary nominal data type, where 1 is survived and 0 is not survived.
#
#
# * <code>Pclass:</code>  The passenger's ticket class. The 'Pclass' variable is an ordinal data type for the 'Ticket' class, a proxy for socio-economic status (SES), representing 1-first (upper class), 2-second (middle class), and 3-third (lower class).
#
#
# * <code>Name:</code>   The passenger's first and last name. The Name variable is a nominal data type. It can be used in feature engineering to derive gender from title, family size from last name, and SES from titles such as Doctor or Lord. Since these variables already exist, we will use them to see if a title such as Doctor or Lord makes a difference
#
#
# * <code>Sex:</code>   The passenger's gender. The Sex variables are nominal/categorical data types. For model calculation purposes these will be converted to numeric variables.
#
#
# * <code>Sibsp:</code>  represents the number of related siblings/spouses on board
#
#
# * <code>Parch:</code>  represents the number of related parents/children on board. This can be used for feature engineering to create family size.
#
# * <code>Ticket:</code>  ticket number. A random variable at first glance, a unique identifier that has no effect on the outcome variable. The Pclass variable is an ordinal data type for this attribute.
#
#
# * <code>Fare:</code>  the fare for the ticket.
#
#
# * <code>Cabin:</code>  cabin, the Cabin variable is a nominal data type that can be used in feature engineering to approximate the position on the ship at the time of the incident and the SES from deck levels. However, because there are many null values, it does not add value and will therefore likely be excluded from the analysis.
#
#
# * <code>Embarked:</code>  starting port (C = Cherbourg; Q = Queenstown; S = Southampton).The Embarked variables are nominal/categorical data types. For the purposes of calculating the model, they will be converted to numeric variables.
#
# The selected features will allow us to determine the value of the result variable. The value we will be examining/predicting is the attribute "Survival" (0/1).

# %% [markdown]
#  ### <a id="I.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3 Project assumptions 🎯</p>

# %% [markdown]
#  ### <a id="I.3.1"></a><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.1 Defining the problem</p>

# %% [markdown]
# This project will be implemented based on a real dataset, provided by the project organizer. The goal is to use this dataset and machine learning to create a predictive model that estimates a passenger's chances of survival.

# %% [markdown]
#  ### <a id="I.3.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.2 Assessing the scope</p>

# %% [markdown]
# The entire project was done in Python, using Jupyter. Defining the scope of the project, its purpose and priorities determines the type of approach to it.
# In this case, the main goal is to achieve a predictive model result that exceeds the satisfaction value achieved by the organizer, namely **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">Accuracy = 0.77990</mark>**

# %% [markdown]
#  ### <a id="I.3.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.3 Success metric</p>

# %% [markdown]
# The indicators of success specified in the requirements are in this case: **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">Accuracy, F1 score, AUC</mark>** .
# Accuracy - this metric tells us about the ratio of well-made classifications to the number of all classifications made. It is expressed in percentages and everyone will understand it immediately. But it also has disadvantages and one of them is a situation in which we have an unbalanced set. Accuracy can therefore be very misleading.
#
# Therefore, an additional indicator of success is the F1 metric, which is the harmonic mean of the two values ​​below:
# * Precision - This metric tells us roughly how much we can trust our positive predictions in a given class. It is defined as:
# tp – true positive is an observation correctly assigned to the analyzed class
# fp – false positive is an observation incorrectly assigned.
# * Recall - the concept behind recall is similar to precision, but it tells us how many observations we have lost for a given class. Here we use the following equation:
#
# So we can have a situation where accuracy is supposedly quite good, but precision and recall are not so good. That is why it is also useful to consider the F1 metric, which gives us a single number (between 1 and 0, where 1 is the best situation) that evenly considers precision and recall.

# %% [markdown]
#  ### <a id="I.3.4"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.4 Feasibility  of the ML application</p>

# %% [markdown]
# The feasibility of the project plan should be assessed to decide whether you are able to build a reliable predictive model with such a small sample of data. Or, can we get new data?
#
# Feature engineering will be used for this purpose to obtain a more complete set of predictive attributes. An additional aspect that will affect the assessment of the project feasibility is the provided test data set, which will be used to verify the quality of the obtained predictive model.

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="II"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">II <span style='color:#CDA63A'>|</span>DATA COLLECTION AND PREPARATION 👨‍💻</div>

# %% [markdown]
#  ### <a id="II.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.1 Import libraries and data files💾</p>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import warnings

pd.set_option('float_format', '{:.3f}'.format)
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
pd.options.display.max_colwidth = 1000
# pd.options.display.precision = 5
warnings.filterwarnings('ignore')

background_color = '#f0f0f0'
background_color2 = '#FFFFFF'
sns.set_style("whitegrid", {"axes.facecolor": background_color2})

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
#  ### <a id="II.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2 Exploratory Data Analysis (EDA)📊</p>

# %%
# df is created only to explore data for EDA 
df= train.copy()

# %% [markdown]
#  ### <a id="II.2.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.1 Reading Data & Target Class Distribution 📚</p>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171  7.250   NaN        S
# 1      0          PC 17599 71.283   C85        C
# 2      0  STON/O2. 3101282  7.925   NaN        S
# 3      0            113803 53.100  C123        S
# 4      0            373450  8.050   NaN        S

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
surv = df['Survived'].value_counts()
surv
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
chart = sns.countplot(x='Survived',
              data=train,
              palette='viridis_r')
plt.title('Class Distribution')
chart.bar_label(chart.containers[0])
plt.show()

# %%
fig = plt.figure(figsize=(20, 20))
sns.catplot(data=df, x='Pclass', y='Survived', hue='Sex', kind="bar", palette='viridis')
plt.title('Survived Distribution by Sex');
plt.show()

# %% [markdown]
#  ### <a id="II.2.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.2 Statistical Summary 🔢</p>

# %%
def statistical_summary_numerical(df: pd.DataFrame):
    df = df.select_dtypes(include='number')
    desc = pd.DataFrame(index=df.columns.to_list())
    desc['type'] = df.dtypes
    desc['count'] = df.count()
    desc['nunique'] = df.nunique()
    desc['%unique'] = desc['nunique'] / len(df) * 100
    desc['null'] = df.isnull().sum()
    desc['%null'] = desc['null'] / len(df) * 100
    desc = pd.concat([desc, df.describe().T.drop('count', axis=1)], axis=1)
    desc["skew"] = df.skew()
    desc["kurtosis"] = df.kurtosis()
    desc = desc.round(2)
    return desc

statistical_summary_numerical(df)
# Out:
#              type  count  nunique  %unique  null  %null   mean    std   min  \
# Survived    int64    891        2     0.22     0   0.00   0.38   0.49  0.00
# Pclass      int64    891        3     0.34     0   0.00   2.31   0.84  1.00
# Age       float64    714       88     9.88   177  19.87  29.70  14.53  0.42
# SibSp       int64    891        7     0.79     0   0.00   0.52   1.10  0.00
# Parch       int64    891        7     0.79     0   0.00   0.38   0.81  0.00
# Fare      float64    891      248    27.83     0   0.00  32.20  49.69  0.00
#
#             25%    50%   75%     max  skew  kurtosis
# Survived   0.00   0.00   1.0    1.00  0.48     -1.78
# Pclass     2.00   3.00   3.0    3.00 -0.63     -1.28
# Age       20.12  28.00  38.0   80.00  0.39      0.18
# SibSp      0.00   0.00   1.0    8.00  3.70     17.88
# Parch      0.00   0.00   0.0    6.00  2.75      9.78
# Fare       7.91  14.45  31.0  512.33  4.79     33.40

# %%
def statistical_summary_categorical(df: pd.DataFrame):
    df = df.select_dtypes(include='object')
    desc = pd.DataFrame(index=df.columns.to_list())
    desc['type'] = df.dtypes
    desc['count'] = df.count()
    desc['nunique'] = df.nunique()
    desc['%unique'] = desc['nunique'] / len(df) * 100
    desc['null'] = df.isnull().sum()
    desc['%null'] = desc['null'] / len(df) * 100
    return desc

statistical_summary_categorical(df)
# Out:
#             type  count  nunique     %unique  null      %null
# Name      object    891      891  100.000000     0   0.000000
# Sex       object    891        2    0.224467     0   0.000000
# Ticket    object    891      681   76.430976     0   0.000000
# Cabin     object    204      147   16.498316   687  77.104377
# Embarked  object    889        3    0.336700     2   0.224467

# %%
print(f'{df.memory_usage().sum()/(1000000)} MB')
# Out:
# 0.085536 MB

# %% [markdown]
#  ### <a id="II.2.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.3 Correlation Matrics🎛️</p>

# %%
df_2= train.copy()
df_2 = df_2.drop(columns="PassengerId")
object_columns = df_2.select_dtypes(include=['object'])

matrix = df_2.copy()
for i in object_columns:
    matrix[i]  = matrix[i].rank(method='dense')

# %%
# matrix2 = df_2.copy()
plt.figure(figsize=(8,6))
temp= matrix
# temp=train.drop('id',axis=1)
temp=temp.apply(lambda x : pd.factorize(x)[0] if x.dtype=='object'else x)
sns.heatmap(temp.corr(),annot=True,cmap='viridis_r')
plt.show()

# %%
sns.pairplot(df, hue='Survived', palette='viridis_r')

# %% [markdown]
#  ### <a id="II.2.4"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.4 Missing values</p>

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin       687
# Age         177
# Embarked      2
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# dtype: int64

# %%
numerical_cols = df.select_dtypes(exclude=['object', 'category'])
categorical_cols = df.select_dtypes(include=['object', 'category'])

def fill_empty_categorical(df):
    for i in categorical_cols:
        df[i].fillna(df[i].mode()[0], inplace=True)
    return df

def fill_empty_numerical(df):
    for i in numerical_cols:
        df[i].fillna(df[i].median(), inplace=True)  
    return df

df = fill_empty_categorical(df)
df = fill_empty_numerical(df)


def convert_types (df):
    for i in categorical_cols:
         df[i] = df[i].astype('category')
    for i in numerical_cols:
         df[i] = df[i].astype('int32')  
    return df
df = convert_types(df)

# %% [markdown]
#  ### <a id="II.2.5"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5 Finding any relations or trends considering multiple features</p>

# %% [markdown]
# In order, I will do univariate analysis on all column to get a grasp of sitation and focus on survival which is main and in process i will also try to get insights to fill those missing values

# %% [markdown]
# #### <a id="II.2.5.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.1  Distribution of numerical features 📈</p>

# %%
# Histograms for numerical features
numerical_features = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature].dropna(), kde=True, bins=30, color='#008000')
    plt.title(f'Distribution of {feature}', fontsize=15)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.show()

# Box plots for numerical features
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[feature].dropna(), color='#008000')
    plt.title(f'Box plot of {feature}', fontsize=15)
    plt.xlabel(feature, fontsize=12)
    plt.show()

# countplot for selected features
categorical_features = ['Sex', 'Embarked', 'Pclass']
for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=df[feature], color='#008000')
    plt.title(f'Count plot of {feature}', fontsize=15)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.show()

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> The most no. of people are in 3rd class but no. of people in 1st and 2nd were almost same
# <li> Most people board in  Southampton England followed by Cherbourg,France and then Queenstown,Ireland
# <li> While Fare is skewed but age is in normal distribtion
# </ul>
# </div>

# %% [markdown]
# #### <a id="II.2.5.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.2  Dependency diagram 'Survived' - 'Pclass'</p>

# %%
pd.crosstab(df.Pclass, df.Survived, margins=True).style.background_gradient(cmap='viridis_r')
# Out:
# <style type="text/css">
# #T_d391d_row0_col0, #T_d391d_row1_col1, #T_d391d_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d391d_row0_col1 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_d391d_row0_col2 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_d391d_row1_col0 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_d391d_row2_col0 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_d391d_row2_col1 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_d391d_row2_col2 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_d391d_row3_col0, #T_d391d_row3_col1, #T_d391d_row3_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d391d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_d391d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d391d_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li>  Maximum number of passengers are in 3rd class (~55% of all passengers)
# <li>  Most of the 3rd class passengers did not survive.
# <li>  1st class passengers had the highest percentage of survived.
# </ul>
# </div>

# %% [markdown]
# #### <a id="II.2.5.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.3  Dependency diagram 'Survived' – 'Pclass' – 'Sex'</p>

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass,margins=True).style.background_gradient(cmap='viridis_r')
# Out:
# <style type="text/css">
# #T_187b4_row0_col0, #T_187b4_row0_col1, #T_187b4_row0_col3, #T_187b4_row3_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_187b4_row0_col2, #T_187b4_row1_col2 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_187b4_row1_col0 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_187b4_row1_col1 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_187b4_row1_col3 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_187b4_row2_col0 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_187b4_row2_col1, #T_187b4_row2_col3 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_187b4_row2_col2 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_187b4_row3_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_187b4_row3_col1 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_187b4_row3_col3 {
#   background-color: #eae51a;
#   color: #000000;
# }
# ...

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> The greatest chance for survival had female in 1st (97%) and 2nd class (79%)
# <li> Female in 3rd class had even better chance than male in 1st (50%)
# <li> The best chance for male was in 1st class (38%)
# <li> Sex than Pclass seem to be one of most important factors in predicting who survived
# </ul>
# </div>

# %% [markdown]
# #### <a id="II.2.5.4"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.4  Dependency diagram 'Survived' – 'Sex'</p>

# %%
fig = plt.figure(figsize=(20, 20))
sns.catplot(data=df, x='Pclass', y='Survived', hue='Sex', kind="bar", palette='viridis')
plt.title('Survived Distribution by Sex');
plt.show()

# %%
fig = plt.figure(figsize = (15,8))

# Survived distribution for male and female of all ages

sub = fig.add_subplot(2,2,1)
chart = sns.histplot(data=df[df['Sex']=='female'], x='Age', 
                     hue='Survived', palette = 'viridis',
                     kde=True, bins=16,
                     stat='percent').set(title='Fig.3 Survived distribution for female')

# chart 4: survived distribution for male

sub = fig.add_subplot(2,2,2)
chart = sns.histplot(data=df[df['Sex']=='male'], x='Age', 
                     hue='Survived', palette = 'viridis', 
                     kde=True, bins=16, 
                     stat='percent').set(title='Fig.4 Survived distribution for male')

plt.show()

# %% [markdown]
# #### <a id="II.2.5.5"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.5  Analysis of survival chances by age group</p>

# %%
fig = plt.figure(figsize = (15,8))

# Survived distribution for all ages

sub = fig.add_subplot(2,2,1)
chart = sns.histplot(data=df, x='Age', 
                     hue='Survived', palette = 'viridis', kde=True, 
                     bins=20,stat='percent').set(title='Fig.1')

sub = fig.add_subplot(2,2,2)
chart = sns.kdeplot(data=df, x='Age', shade = True,
                     hue='Survived', palette = 'viridis').set(title='Fig.2')

plt.show()

# %%
# defining age-divided groups
def age_group(age):
    if age < 18:
        return '0-17'
    elif age < 30:
        return '18-29'
    elif age < 50:
        return '30-49'
    else:
        return '50+'

# Group data by age group and passenger class and calculate survival rate
df['AgeGroup'] = df['Age'].apply(age_group)
survival_rates = df.groupby(['AgeGroup', 'Pclass'])['Survived'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.catplot(x='Pclass', y='Survived', hue='AgeGroup', kind='bar', data=survival_rates, palette='viridis')
plt.title('Survival rate by age group and passenger class', fontsize=15)
plt.xlabel('Passenger class', fontsize=12)
plt.ylabel('Survival rate', fontsize=12)
plt.show()

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> The greatest chance for survival had 1st gropup (0-17) in each of class
# <li> The smallest chance for survival had 1st gropup (50+) in each of class
# <li> Age seem to be one of most important factors in predicting who survived
# </ul>
# </div>

# %% [markdown]
# #### <a id="II.2.5.6"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.6  Analysis of 'Embarked'</p>

# %%
fig,ax=plt.subplots(2,2,figsize=(16,10))

chart = sns.countplot(data=df, x='Embarked', ax=ax[0,0], palette="viridis")
ax[0,0].set_title('Number Of Passengers Boarded')
chart.bar_label(chart.containers[0])

chart2 = sns.countplot(data=df, x='Embarked', hue='Sex', ax=ax[0,1], palette="viridis")
ax[0,1].set_title('Male-Female Count By Port')
chart2.bar_label(chart2.containers[0])
chart2.bar_label(chart2.containers[1])

chart3 = sns.countplot(data=df, x='Embarked', hue='Survived', ax=ax[1,0], palette="viridis")
ax[1,0].set_title('Survivors By Port')
chart3.bar_label(chart3.containers[0])
chart3.bar_label(chart3.containers[1])

chart4=sns.countplot(data=df, x='Embarked', hue='Pclass', ax=ax[1,1], palette="viridis")
ax[1,1].set_title('Pclass Count By Port')
chart4.bar_label(chart4.containers[0])
chart4.bar_label(chart4.containers[1])
chart4.bar_label(chart4.containers[2])
# Out:
# [Text(0, 0, '353'), Text(0, 0, '66'), Text(0, 0, '72')]

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> Most of the passengers embarked at Cherbourg were 1st class.
#
# <li> Most of the passengers embarked at Cherbourg survived.
#
# <li> The Southampton was by far the most male.
#
# <li> The Southampton passengers have the lowest percentage of survivors.
#
# <li> Queenstown, despite the overwhelming number of 3rd class passengers, has a fairly high percentage of survivors, which is probably due to the large number of women and, consequently, children.
# </ul>
# </div>

# %% [markdown]
# #### <a id="II.2.5.7"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.7  Analysis of survival chances depending on family size</p>

# %%
# Plot survivability by parch
plt.figure(figsize=(8, 6))
sns.barplot(x='Parch', y='Survived', data=df, palette='viridis')
plt.title('Survivability by Number of Parents/Children Aboard')
plt.xlabel('Number of Parents/Children')
plt.ylabel('Survival Rate')
plt.show()

# Plot survivability by sibsp
plt.figure(figsize=(8, 6))
sns.barplot(x='SibSp', y='Survived', data=df, palette='viridis')
plt.title('Survivability by Number of Siblings/Spouses Aboard')
plt.xlabel('Number of Siblings/Spouses')
plt.ylabel('Survival Rate')
plt.show()

# %%
# Create a new column for family size
df['family_size'] = df['SibSp'] + df['Parch']+1#including passenger as well
# Plot survivability by family size
plt.figure(figsize=(8, 6))
sns.barplot(x='family_size', y='Survived', data=df, palette='viridis')
plt.title('Survivability by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> Statistically, the greatest chances of survival were those from families of 2, 3 and even four people, which was probably influenced by the fact that children and women had priority over lifeboats,
# <li> Unfortunately, for families of 5 and more, these chances decreased dramatically.
#
# <li> Statistically, passengers who were alone on the cruise had an average chance of survival, this result is probably lowered by the large number of single men.
# </ul>
# </div>

# %%
df['family_size'] = df['SibSp'] + df['Parch']+1
fig,ax=plt.subplots(figsize=(8,6))
sns.countplot(data=df, x='family_size',  palette="viridis")
# Out:
# <Axes: xlabel='family_size', ylabel='count'>

# %% [markdown]
# #### <a id="II.2.5.8"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.8  Analysis of survival chances depending on 'Age' – 'Fare'</p>

# %%
# Create a scatter plot with fares, age, and passenger class
plt.figure(figsize=(6, 6))
sns.relplot(x='Age', y='Fare', hue='Survived', data=df, palette='viridis_r', height=6)
plt.title('Relationship between Age, Fare, and Passenger Class', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Fare', fontsize=12)
plt.show()

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Conclusions:
# <li> Passengers with the cheapest tickets definitely had the lowest chances of survival.
# <li> For children under 8, the class of the ticket  was not significant, most survived
# </ul>
# </div>

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="III"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">III <span style='color:#CDA63A'>|</span>DATA PRE-PROCESSING (data cleaning)🧪</div>

# %% [markdown]
# Data Cleaning - dealing with imbalanced classes(target), analyzing wrong-labeled data, removing duplicates and unnecessary columns, convert types (downcasting), feature selection, feature engineering,  data augmentation

# %%
X = train.drop(columns=['Survived', 'PassengerId']).copy()
y = train['Survived']
test = test.drop(columns=['PassengerId']).copy()

# %% [markdown]
#  ### <a id="III.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.1 Convert Types (Downcasting)</p>

# %%
# Aggregate Categorical and Numerical
to_boolen = [i for i in X.columns if 
             X[i].nunique() < 3 and
             (X[i].dtype =='object'or
              X[i].dtype =='int64' or
              X[i].dtype =='float64')
            ]

object_to_categorical = [i for i in X.columns if
                         X[i].nunique() >=3 and
                         X[i].dtype =='object']

numerical_int = X.select_dtypes(include=['int64'])

numerical_float = X.select_dtypes(include=['float64'])


categorical_dummies = [i for i in X.columns if
                       X[i].nunique() >=3 and
                       X[i].nunique() <11 and
                       X[i].dtype =='object']

def convert_types (df):
#     for i in to_boolen:
#          df[i] = df[i].astype('bool')
    for i in object_to_categorical:
         df[i] = df[i].astype('category')
    for i in numerical_int:
         df[i] = df[i].astype('int32')  
    for i in numerical_float:
         df[i] = df[i].astype('float32') 
    return df

X = convert_types(X)
test = convert_types(test)

# %% [markdown]
#  ### <a id="III.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.2 Feature Engineering 👨‍🔬</p>

# %%
# Cabin
# X['Cabin'] = X['Cabin'].apply(lambda x: 0 if type(x) == float else 1)
# test['Cabin'] = test['Cabin'].apply(lambda x: 0 if type(x) == float else 1)

# %%
# Tittle
def add_title(df):
    # Pull and transform the title from Name
    df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.',expand=False)
    df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],'Rare')
    df['Title'] = df['Title'].replace('Mlle','Miss')
    df['Title'] = df['Title'].replace('Ms','Miss')
    df['Title'] = df['Title'].replace('Mme','Mrs')  
    return df

X = add_title(X)
test= add_title(test)

X = X.drop(columns='Name')
test = test.drop(columns='Name')

# %%
# Family Size
X['Family_Size'] = X['SibSp'] + X['Parch'] + 1    #including passenger as well
test['Family_Size'] = test['SibSp'] + test['Parch']+1

# %%
# Family size groups
# def family_size_group(size):
#     if size < 4:
#         return 'small'
#     else:
#         return 'big'

# # Group data by age group and passenger class and calculate survival rate
# X['Family_Size_ID'] = X['Family_Size'].apply(family_size_group)
# test['Family_Size_ID'] = test['Family_Size'].apply(family_size_group)

# %%
# Age-divided groups
def age_group(age):
    if age < 8:
        return '0-7'
    elif age < 15:
        return '8-14'
    elif age < 20:
        return '15-19'
    elif age < 30:
        return '20-29'
    elif age < 50:
        return '30-49'
    else:
        return '50+'

# Group data by age group and passenger class and calculate survival rate
X['AgeGroup'] = X['Age'].apply(age_group)
test['AgeGroup'] = test['Age'].apply(age_group)

# %%
# Age*Class
X['Age*Class'] = X['Age'] * X['Pclass']
test['Age*Class'] = test['Age'] * test['Pclass']

# %% [markdown]
#  ### <a id="III.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.3 Skewness of distributions 📉</p>

# %%
features = X.select_dtypes(include=['number']).columns.tolist()

plt.figure(figsize=(16, 10))
for i, col in enumerate(features):
    plt.subplot(2, 4, i+1) 
    sns.histplot(data=X, x=col,
                 kde=True,
                 color= '#008000',
                 palette='magma'
                 )
    plt.axvline(x=X[col].median(),
            color='red',
            ls='--', 
            lw=2.5,
            )
plt.tight_layout()
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
#  ### <a id="III.4"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.4 Detect Outliers 🧐</p>

# %%
def calculate_outliers_percentage(df):

    outlier_counts = {}
    for column in df.select_dtypes(include=['number']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Calculate outliers
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        outlier_counts[column] = len(outliers)

    # Print the percentage of outliers for each column
    for column in outlier_counts:
        percentage = (outlier_counts[column] / len(df)) * 100
        print(f"Percentage of outliers in {column}: {percentage:.2f}%")


calculate_outliers_percentage(X)
# Out:
# Percentage of outliers in Pclass: 0.00%
# Percentage of outliers in Age: 0.00%
# Percentage of outliers in SibSp: 0.00%
# Percentage of outliers in Parch: 23.91%
# Percentage of outliers in Fare: 0.00%
# Percentage of outliers in Family_Size: 10.21%
# Percentage of outliers in Age*Class: 1.35%

# %%
features = X.select_dtypes(include=['number']).columns.tolist()
features
# Out:
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Family_Size', 'Age*Class']

# %%
plt.figure(figsize=(16,10))

for i,col in enumerate(features):    
    plt.subplot(2,4,i + 1)
    sns.boxplot(y=col, data=X, palette='viridis_r')
    #plt.ylabel('')

plt.tight_layout()

plt.show()

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="IV"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">IV <span style='color:#CDA63A'>|</span>DATA PROCESSING 🛠️</div>

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, MinMaxScaler, StandardScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder 
from sklearn.model_selection import cross_val_score,StratifiedKFold, KFold, GridSearchCV, RandomizedSearchCV, RepeatedStratifiedKFold, RepeatedKFold
from sklearn.metrics import cohen_kappa_score, accuracy_score, adjusted_mutual_info_score, mean_absolute_error, r2_score, mean_squared_error

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import  DecisionTreeClassifier

from sklearn.feature_selection import SelectFromModel, RFECV, SelectKBest, chi2, f_classif,f_regression, SelectFromModel, RFE, mutual_info_classif, SelectPercentile
from sklearn.linear_model import Lasso
from boruta import BorutaPy

# %% [markdown]
#  ### <a id="IV.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">IV.1 Filling nulls</p>

# %%
numerical_cols = X.select_dtypes(exclude=['object', 'category'])
categorical_cols = X.select_dtypes(include=['object', 'category'])

def fill_empty_categorical(df):
    for i in categorical_cols:
        df[i].fillna(df[i].mode()[0], inplace=True)
    return df

def fill_empty_numerical(df):
    for i in numerical_cols:
        df[i].fillna(df[i].median(), inplace=True)  
    return df

X = fill_empty_categorical(X)
X = fill_empty_numerical(X)

test = fill_empty_categorical(test)
test = fill_empty_numerical(test)

# %% [markdown]
#  ### <a id="IV.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">IV.2 Categorical data transformation</p>

# %%
categorical_cols = [cname for cname in X.columns if  
                        X[cname].dtype in ['category','object'] and X[cname].nunique() <5]

X = pd.get_dummies(X, columns=categorical_cols)
test = pd.get_dummies(test, columns=categorical_cols)

# %%
categorical_columns = X.select_dtypes(include=['category', 'object']).columns

encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X[categorical_columns] = encoder.fit_transform(X[categorical_columns].astype(str))
test[categorical_columns] = encoder.fit_transform(test[categorical_columns].astype(str))

# %% [markdown]
#  ### <a id="IV.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">IV.3 Normalizing data</p>

# %%
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
test = pd.DataFrame(scaler.fit_transform(test), columns=test.columns)

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="V"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">V <span style='color:#CDA63A'>|</span>MODEL ENGINEERING 🤖</div>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import keras
from keras import layers
import keras_tuner

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, random_state=42)

# %% [markdown]
#  ### <a id="V.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.1 Model 1</p>

# %%
def call_existing_code(units, activation, dropout, lr):
    model = keras.Sequential()
    model.add(layers.Flatten())
    model.add(layers.Dense(units=units, activation=activation))
    if dropout:
        model.add(layers.Dropout(rate=0.25))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )
    return model


def build_model_1(hp):
    units = hp.Int("units", min_value=128, max_value=512, step=32)
    activation = hp.Choice("activation", ["relu", "tanh"])
    dropout = hp.Boolean("dropout")
    lr = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    # call existing model-building code with the hyperparameter values.
    model = call_existing_code(
        units=units, activation=activation, dropout=dropout, lr=lr
    )
    return model


build_model_1(keras_tuner.HyperParameters())
# Out:
# <Sequential name=sequential_1, built=False>

# %% [markdown]
#  ### <a id="V.1.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.1.1 Model 1 Tuning - RandomearchCV</p>

# %%
tuner_1 = keras_tuner.RandomSearch(
    hypermodel=build_model_1,
    objective="val_accuracy",
    max_trials=10,
    executions_per_trial=2,
    overwrite=True,
    directory="my_dir",
    project_name="helloworld",
)

tuner_1.search(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid))
# Out:
# Trial 10 Complete [00h 00m 09s]
# val_accuracy: 0.8407821357250214
#
# Best val_accuracy So Far: 0.8463687002658844
# Total elapsed time: 00h 01m 28s

# %%
models = tuner_1.get_best_models(num_models=2)
best_model = models[0]
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 288)            │         4,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,185 (20.25 KB)
#  Trainable params: 5,185 (20.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tuner_1.results_summary()
# Out:
# Results summary
# Results in my_dir\helloworld
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 02 summary
# Hyperparameters:
# units: 288
# activation: relu
# dropout: False
# lr: 0.00414703306340739
# Score: 0.8463687002658844
#
# Trial 00 summary
# Hyperparameters:
# units: 192
# activation: relu
# dropout: False
# lr: 0.002871041043695418
# Score: 0.8435754179954529
#
# Trial 08 summary
# Hyperparameters:
# units: 320
# activation: relu
# dropout: True
# lr: 0.0062139741793917755
# Score: 0.8435754179954529
#
# Trial 09 summary
# Hyperparameters:
# units: 256
# activation: relu
# dropout: True
# lr: 0.0017317011141003704
# Score: 0.8407821357250214
#
# Trial 01 summary
# Hyperparameters:
# units: 384
# activation: relu
# dropout: False
# lr: 0.0005083974753359558
# Score: 0.8324022591114044
#
# Trial 04 summary
# Hyperparameters:
# units: 480
# activation: relu
# dropout: True
# lr: 0.00031418620419296233
# Score: 0.8240223526954651
#
# ...

# %%
# Get the top 5 hyperparameters.
best_hps = tuner_1.get_best_hyperparameters(5)
# Build the model with the best hp.
model_X = build_model_1(best_hps[0])
# Fit with the entire dataset.
x_all = np.concatenate((X_train, X_valid))
y_all = np.concatenate((y_train, y_valid))

early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=25, min_lr=1e-6)

history_X = model_X.fit(x=x_all, 
            y=y_all, 
            epochs=550, 
            verbose=1, 
            batch_size=50,
            validation_data=(X_valid, y_valid),
            callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6614 - loss: 0.5831 - val_accuracy: 0.7765 - val_loss: 0.4663 - learning_rate: 0.0041
# Epoch 2/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7823 - loss: 0.4725 - val_accuracy: 0.7989 - val_loss: 0.4286 - learning_rate: 0.0041
# Epoch 3/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8081 - loss: 0.4337 - val_accuracy: 0.7989 - val_loss: 0.4157 - learning_rate: 0.0041
# Epoch 4/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8287 - loss: 0.4196 - val_accuracy: 0.7989 - val_loss: 0.4090 - learning_rate: 0.0041
# Epoch 5/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8097 - loss: 0.4313 - val_accuracy: 0.8101 - val_loss: 0.3988 - learning_rate: 0.0041
# Epoch 6/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8383 - loss: 0.3989 - val_accuracy: 0.8268 - val_loss: 0.3894 - learning_rate: 0.0041
# Epoch 7/550
# ...

# %% [markdown]
#  ### <a id="V.1.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.1.2 Model 1 Validation</p>

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_X.history['loss'])
plt.plot(history_X.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history_X.history['accuracy'])
plt.plot(history_X.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.show()

# %% [markdown]
#  ### <a id="V.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.2 Model 2</p>

# %%
def build_model_2(hp):
    model = keras.Sequential()
    model.add(layers.Flatten())
    model.add(layers.Dense(16, activation=tf.nn.relu))
    model.add(layers.Dropout(rate=0.2))
    model.add(layers.Dense(16, activation=tf.nn.relu))
    model.add(layers.Dropout(rate=0.1))
    # Tune the number of layers.
    for i in range(hp.Int("num_layers", 1, 3)):
        model.add(
            layers.Dense(
                        # Tune number of units separately.
                        units=hp.Int(f"units_{i}", min_value=4, max_value=16, step=4),
                        activation=hp.Choice("activation", ["sigmoid","relu", "tanh"]),
#                         kernel_regularizer=keras.regularizers.l1_l2(l1=0.1, l2=0.01)
                        )
            
                )
#         model.add(layers.Dropout(rate=0.1))
    if hp.Boolean("dropout"):
          model.add(layers.Dropout(rate=0.2))
    model.add(layers.Dense(1, activation="sigmoid"))
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )
    return model


build_model_2(keras_tuner.HyperParameters())
# Out:
# <Sequential name=sequential_2, built=False>

# %% [markdown]
#  ### <a id="V.2.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.2.1 Model 2 Tuning - RandomizedSearchCV</p>

# %%
tuner_2 = keras_tuner.RandomSearch(
    hypermodel=build_model_2,
    objective="val_accuracy",
    max_trials=10,
    executions_per_trial=2,
    overwrite=True,
    directory="my_dir",
    project_name="helloworld",
)

tuner_2.search(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid))
# Out:
# Trial 10 Complete [00h 00m 11s]
# val_accuracy: 0.8184357583522797
#
# Best val_accuracy So Far: 0.8268156349658966
# Total elapsed time: 00h 01m 52s

# %%
models_2 = tuner_2.get_best_models(num_models=2)
best_model_2 = models_2[0]
best_model_2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ...

# %%
# Get the top 5 hyperparameters.
best_hps_2 = tuner_2.get_best_hyperparameters(5)
# Build the model with the best hp.
model_X_2 = build_model_2(best_hps_2[0])
# Fit with the entire dataset.
x_all = np.concatenate((X_train, X_valid))
y_all = np.concatenate((y_train, y_valid))

early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=25, min_lr=1e-6)

history_X_2 = model_X_2.fit(x=x_all, 
            y=y_all, 
            epochs=550, 
            verbose=1, 
            batch_size=50,
            validation_data=(X_valid, y_valid),
            callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5412 - loss: 2.5351 - val_accuracy: 0.6480 - val_loss: 2.1032 - learning_rate: 0.0045
# Epoch 2/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6921 - loss: 1.9965 - val_accuracy: 0.7542 - val_loss: 1.6283 - learning_rate: 0.0045
# Epoch 3/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7226 - loss: 1.5433 - val_accuracy: 0.7598 - val_loss: 1.2237 - learning_rate: 0.0045
# Epoch 4/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7942 - loss: 1.1466 - val_accuracy: 0.7877 - val_loss: 0.9184 - learning_rate: 0.0045
# Epoch 5/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7580 - loss: 0.8848 - val_accuracy: 0.7877 - val_loss: 0.7123 - learning_rate: 0.0045
# Epoch 6/550
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7863 - loss: 0.7004 - val_accuracy: 0.8045 - val_loss: 0.6067 - learning_rate: 0.0045
# Epoch 7/550
# ...

# %% [markdown]
#  ### <a id="V.2.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.2.2 Model 2 Validation</p>

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_X_2.history['loss'])
plt.plot(history_X_2.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history_X_2.history['accuracy'])
plt.plot(history_X_2.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.show()

# %% [markdown]
#  ### <a id="V.3"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.3 Model 3</p>

# %%
def build_model_3(hp):
    model = keras.Sequential()
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation="relu"))
    model.add(layers.Dropout(rate=0.1))
    model.add(layers.Dense(512, activation="relu"))
    model.add(layers.Dropout(rate=0.1))
    for i in range(hp.Int("num_layers", 1, 3)):
        model.add(
            layers.Dense(
                        # Tune number of units separately.
                        units=hp.Int(f"units_{i}", min_value=4, max_value=256, step=32),
                        activation=hp.Choice("activation", ["relu", "tanh"]),
#                         kernel_regularizer=keras.regularizers.l1_l2(l1=0.1, l2=0.01)
                        )
                )
        model.add(layers.Dropout(rate=0.1))
#     if hp.Boolean("dropout"):
#          model.add(layers.Dropout(rate=0.2))
    model.add(layers.Dense(1, activation="sigmoid"))
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )
    return model


build_model_3(keras_tuner.HyperParameters())
# Out:
# <Sequential name=sequential_2, built=False>

# %% [markdown]
#  ### <a id="V.3.1"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.3.1 Model 3 Tuning - RandomSearch</p>

# %%
tuner_3 = keras_tuner.RandomSearch(
    hypermodel=build_model_3,
    objective="val_accuracy",
    max_trials=10,
    executions_per_trial=2,
    overwrite=True,
    directory="my_dir",
    project_name="helloworld",
)

tuner_3.search(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid))
# Out:
# Trial 10 Complete [00h 00m 18s]
# val_accuracy: 0.8519552946090698
#
# Best val_accuracy So Far: 0.8575418889522552
# Total elapsed time: 00h 02m 45s

# %%
models_3 = tuner_3.get_best_models(num_models=2)
best_model_3 = models_3[0]
best_model_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ...

# %%
tuner_3.results_summary()
# Out:
# Results summary
# Results in my_dir\helloworld
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 01 summary
# Hyperparameters:
# num_layers: 1
# units_0: 36
# activation: tanh
# lr: 0.00045018693410434345
# units_1: 228
# Score: 0.8575418889522552
#
# Trial 04 summary
# Hyperparameters:
# num_layers: 2
# units_0: 100
# activation: relu
# lr: 0.0005023114104783992
# units_1: 68
# units_2: 68
# Score: 0.8575418889522552
#
# Trial 08 summary
# Hyperparameters:
# num_layers: 1
# units_0: 68
# activation: relu
# lr: 0.0008240122217275786
# units_1: 4
# units_2: 100
# Score: 0.8575418889522552
#
# Trial 05 summary
# Hyperparameters:
# num_layers: 2
# units_0: 228
# activation: tanh
# lr: 0.001344121154884341
# units_1: 68
# units_2: 4
# Score: 0.8547486066818237
#
# Trial 02 summary
# Hyperparameters:
# num_layers: 3
# units_0: 132
# activation: relu
# lr: 0.0008458403820081236
# units_1: 36
# units_2: 4
# Score: 0.8519552946090698
#
# Trial 07 summary
# ...

# %%
# Get the top 2 hyperparameters.
best_hps_3 = tuner_3.get_best_hyperparameters(5)
# Build the model with the best hp.
model_X_3 = build_model_3(best_hps_3[0])
model_Z_3 = tuner_3.get_best_models()[0]
# Fit with the entire dataset.
x_all = np.concatenate((X_train, X_valid))
y_all = np.concatenate((y_train, y_valid))

early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=25, min_lr=1e-6)

history_Z_3 = model_Z_3.fit(x=x_all, 
            y=y_all, 
            epochs=550, 
            verbose=1, 
            batch_size=128,
            validation_data=(X_valid, y_valid),
            callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8393 - loss: 0.3720 - val_accuracy: 0.8492 - val_loss: 0.3746 - learning_rate: 4.5019e-04
# Epoch 2/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8444 - loss: 0.3730 - val_accuracy: 0.8492 - val_loss: 0.3658 - learning_rate: 4.5019e-04
# Epoch 3/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8586 - loss: 0.3566 - val_accuracy: 0.8436 - val_loss: 0.3573 - learning_rate: 4.5019e-04
# Epoch 4/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8596 - loss: 0.3470 - val_accuracy: 0.8603 - val_loss: 0.3508 - learning_rate: 4.5019e-04
# Epoch 5/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8643 - loss: 0.3374 - val_accuracy: 0.8492 - val_loss: 0.3490 - learning_rate: 4.5019e-04
# Epoch 6/550
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8567 - loss: 0.3514 - val_accuracy: 0.8547 - val_loss: 0.3403 - learning_rate: 4.5019e-04
# Epoch 7/550
# ...

# %%
history_X.history['val_accuracy']
# Out:
# [0.7765362858772278,
#  0.7988826632499695,
#  0.7988826632499695,
#  0.7988826632499695,
#  0.8100558519363403,
#  0.826815664768219,
#  0.826815664768219,
#  0.826815664768219,
#  0.826815664768219,
#  0.8212290406227112,
#  0.8379888534545898,
#  0.8379888534545898,
#  0.832402229309082,
#  0.8603351712226868,
#  0.8547486066818237,
#  0.8659217953681946,
#  0.832402229309082,
#  0.8603351712226868,
#  0.8547486066818237,
#  0.8603351712226868,
#  0.8435754179954529,
#  0.8547486066818237,
#  0.8659217953681946,
#  0.8547486066818237,
#  0.8603351712226868,
#  0.8547486066818237,
#  0.8603351712226868,
#  0.8603351712226868,
#  0.8603351712226868,
#  0.8435754179954529,
#  0.8547486066818237,
#  0.8603351712226868,
#  0.8603351712226868,
#  0.8826815485954285,
#  0.8659217953681946,
#  0.8715083599090576,
#  0.8715083599090576,
#  0.8547486066818237,
#  0.8826815485954285,
#  0.8715083599090576,
#  0.8547486066818237,
#  0.8603351712226868,
#  0.8491619825363159,
# ...

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_X.history['loss'])
plt.plot(history_X.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history_X.history['accuracy'])
plt.plot(history_X.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.show()

# %% [markdown]
#  ### <a id="V.3.2"><p style="background-color: #294B8E;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.3.2 Model 3 evaluate</p>

# %%
model_Z = tuner_3.get_best_models()[0]
model_Z
# Out:
# <Sequential name=sequential, built=True>

# %%
test_loss, test_accuracy = model_Z.evaluate(X_valid, y_valid)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8544 - loss: 0.3867

# %%
best_h_3 = tuner_3.get_best_hyperparameters()[0]
best_h_3.values
# Out:
# {'num_layers': 1,
#  'units_0': 36,
#  'activation': 'tanh',
#  'lr': 0.00045018693410434345,
#  'units_1': 228}

# %%
beast_trial_ = tuner_3.oracle.get_best_trials()[0]
beast_trial_.summary()
# Out:
# Trial 01 summary
# Hyperparameters:
# num_layers: 1
# units_0: 36
# activation: tanh
# lr: 0.00045018693410434345
# units_1: 228
# Score: 0.8575418889522552

# %% [markdown]
# <a id="VI"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">VI <span style='color:#CDA63A'>|</span>CONCLUSION 👩‍🏫</div>

# %% [markdown]
# In the above "project" only three iterations are presented, which turned out to be the best by far. It should be noted that there were definitely more iterations leading to the final result.
#
# Iteration one of the Data Science Framework, seems to converge on 0.77990 submission accuracy. Using the same dataset and different implementation of a decision tree (random forest, xgboost, etc.) with tuning does not exceed the 0.77990 submission accuracy. Interesting for this dataset, the simple decision tree algorithm had the best default submission score and with tuning achieved the same best accuracy score.
#
# Despite tuning, no machine learning algorithm, exceeded the homemade algorithm. The author will theorize, that for small datasets, a manmade algorithm is the bar to beat.
# With that in mind, for iteration two, it was to spend more time on preprocessing and feature engineering. In order to better align the score improve the overall accuracy.
#
# It was analized randomized tuner for nlp projects. In 3 steps was generated totally different aproaches. First model is very simple with high score of dense but score is surprisingly good.
# 2
# The second model was significantly expanded, but the density factor was drastically reduced to a value equal to input. As a result, quality dropped dramatically.
# 3
# The third model, which is a kind of compilation of the previous ones, i.e. extended with high score of dense like 1st model, and with more layers like 2nd. This model received  definitely the best scores.
